# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
family_url = "http://www.fishbase.org/Nomenclature/NominalSpeciesList.php?family=Engraulidae"

html = urllib.request.urlopen(family_url)
html_doc = html.read()
html.close()

# %%
soup = BeautifulSoup(html_doc)
# Out:
# /home/eeb177-student/miniconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/eeb177-student/miniconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
links = soup.find_all("a")

for link in links:
    italics = link.find_all("i")
    for italic in italics:
        print(italic.string)
# Out:
# Lycengraulis grossidens
# Thryssa adelae
# Stolephorus advenus
# Thryssa aestuaria
# Engraulis albidus
# Stolephorus indicus
# Anchoviella alleni
# Engraulis encrasicolus
# Anchoa analis
# Engraulis anchoita
# Stolephorus andhraensis
# Thryssa purava
# Engraulis australis
# Engraulis australis
# Stolephorus apiensis
# Thryssa baelama
# Anchoa spinifer
# Anchoa argentivittata
# Engraulis encrasicolus
# Anchoa cubana
# Pterengraulis atherinoides
# Thryssa dussumieri
# Engraulis australis
# Thryssa baelama
# Stolephorus baganensis
# Stolephorus baganensis
# Anchoviella balboae
# Stolephorus indicus
# Lycengraulis batesii
# Lycengraulis batesii
# Anchoa belizensis
# Anchoviella blackburni
# Anchoa tricolor
# Coilia borneensis
# Stolephorus brachycephalus
# Coilia brachygnathus
# Anchovia macrolepidota
# Anchoviella brevirostris
# Thryssa brevicauda
# Setipinna breviceps
# Setipinna brevifilis
# Anchoviella balboae
# Anchoviella brevirostris
# Cetengraulis edentulus
# Anchoa hepsetus
# Encrasicholina punctifer
# Coilia ramcarati
# Engraulis capensis
# Engraulis encrasicolus
# Stolephorus carpentariae
# Anchoviella carrikeri
# Anchoviella cayennensis
# Engraulis japonicus
# Anchoa chamensis
# Thryssa chefuensis
# Stolephorus chinensis
# Anchoa cayorum
# Anchoa choerostoma
# Coilia dussumieri
# Anchoa starksi
# Anchovia clupeoides
# Coilia mystus
# Stolephorus commersonnii
# Anchoa compressa
# Coilia coomansi
# Lycothrissa crocodilus
# Anchoa cubana
# Anchoa nasus
# Anchoa curta
# Thryssa dayi
# Anchoa delicatissima
# Lycengraulis grossidens
# Encrasicholina devisi
# Stolephorus dubiosus
# Thryssa encrasicholoides
# Coilia dussumieri
# Thryssa dussumieri
# Coilia nasus
# Coilia nasus
# Cetengraulis edentulus
# Anchoa eigenmannia
# Anchoviella elongata
# Thryssa encrasicholoides
# Thryssa encrasicholoides
# Engraulis australis
# Engraulis encrasicolus
# Engraulis encrasicolus
# Cetengraulis mysticetus
# Coilia mystus
# Engraulis eurystole
# Engraulis eurystole
# Anchoa exigua
# Stolephorus indicus
# Lycengraulis figueiredoi
# Setipinna breviceps
# Setipinna phasa
# Anchoa tricolor
# Anchoa marinii
# Anchoa lyolepis
# Coilia mystus
# Lycengraulis poeyi
# Thryssa polybranchialis
# Coilia borneensis
# Lycengraulis grossidens
# Thryssa baelama
# Thryssa mystax
# Anchovia surinamensis
# Coilia mystus
# Anchovia clupeoides
# Encrasicholina heteroloba
# Engraulis ringens
# Encrasicholina punctifer
# Thryssa purava
# Encrasicholina purpurea
# Coilia ramcarati
# Coilia dussumieri
# Thryssa purava
# Coilia ramcarati
# Anchovia macrolepidota
# Thryssa rastrosa
# Coilia rebentischii
# Coilia brachygnathus
# Stolephorus commersonnii
# Coilia reynaldi
# Thryssa kammalensis
# Engraulis ringens
# Cetengraulis edentulus
# Stolephorus ronquilloi
# Stolephorus indicus
# Engraulis encrasicolus
# Coilia rebentischii
# Anchoa tricolor
# Thryssa baelama
# Stolephorus indicus
# Lycengraulis grossidens
# Anchoa mundeoloides
# Amazonsprattus scintilla
# Stolephorus indicus
# Anchoa scofieldi
# Thryssa scratchleyi
# Cetengraulis edentulus
# Thryssa setirostris
# Stolephorus shantungensis
# Lycengraulis grossidens
# Thryssa spinidens
# Anchoa spinifer
# Anchoa starksi
# Thryssa stenosoma
# Thryssa mystax
# Anchovia surinamensis
# Engraulis ringens
# Setipinna taty
# Stolephorus teguhi
# Setipinna phasa
# Setipinna taty
# Setipinna tenuifilis
# Anchoa spinifer
# Stolephorus tri
# Anchoa tricolor
# Anchoa trinitatis
# Anchoa exigua
# Setipinna phasa
# Stolephorus commersonnii
# Stolephorus carpentariae
# Anchoa pectoralis
# Anchoviella vaillanti
# Thryssa mystax
# Anchovia surinamensis
# Anchoviella cayennensis
# Thryssa vitrirostris
# Engraulis encrasicolus
# Stolephorus waitei
# Anchoa walkeri
# Setipinna wheeleri
# Thryssa whiteheadi
# Engraulis japonicus

# %%
import urllib.request
import json

api_url = "http://www.fishbase.org/Nomenclature/NominalSpeciesList.php?family=Engraulidae"

raw_json = urllib.request.urlopen(api_url)
decoded_json = raw_json.read().decode("utf-8")
parsed_json = json.loads(decoded_json)
raw_json.close()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-683a8f8f6dd1> in <module>()
#       6 raw_json = urllib.request.urlopen(api_url)
#       7 decoded_json = raw_json.read().decode("utf-8")
# ----> 8 parsed_json = json.loads(decoded_json)
#       9 raw_json.close()
#
# /home/eeb177-student/miniconda3/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# /home/eeb177-student/miniconda3/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /home/eeb177-student/miniconda3/lib/python3.5/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
